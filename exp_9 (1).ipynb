# %% [markdown]
# #1. Data Loading
#
# ---

# %%
# download the diabetes_dataset from
# https://drive.google.com/file/d/12f8fkDqCEvjSfMKux1l9FjxNlBTOXZGF/view?usp=sharing

# And upload it to colab
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-c0d46aec-de8c-491a-8730-3bea694826d5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c0d46aec-de8c-491a-8730-3bea694826d5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
# Use read_csv from pandas to read the file for proceesing
# Read the pima-indians-diabetes.csv dataset into a dataframe say df
df = pd.read_csv("pima-indians-diabetes.csv",header=None)
df.head()
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %% [markdown]
# #2. Perform EDA using following steps
# ---

# %%
# Give names to the columns of the above dataset. Print first 2 records.
df.columns = ['pregnantcount','Plasma glucose concentration','Diastolic blood pressure','Triceps skin fold thickness','2-Hour serum insulin','BMI','Diabetes pedigree function','Age','isdiabetic']
print('First 2 Records')
print(df.head(2),end = '\n\n\n')

# Check if there are any columns with empty/null dataset ?
print('Check if there are any columns with empty/null dataset ?')
print(df.isnull().sum())
print(end = '\n\n\n')

# Find correlation between all predative features w.r.t "HasDiabetes" (target) feature.
print('correlation between all predative features w.r.t "HasDiabetes" (target) feature')
cor = df.corr()['isdiabetic']
print(cor)
print(end = '\n\n\n')
#df.drop("isdiabetic", axis=1).apply(lambda x: x.corr(df.isdiabetic))

# See carefully and find 3 most correlated features to target variable.
print('find 3 most correlated features to target variable')
cor_target = abs(cor)
relevant_features = cor_target[cor_target>0.29]
print(relevant_features)
print(end = '\n\n\n')

# Plot a heatmap of the correlation matrix obtained above.
print('heatmap of the correlation matrix ')
import seaborn as sb
dataplot = sb.heatmap(df.corr(), cmap="YlGnBu", annot=True)

# hint : use heatmap() from seaborn
# Out:
# First 2 Records
#    pregnantcount  Plasma glucose concentration  Diastolic blood pressure  \
# 0              6                           148                        72
# 1              1                            85                        66
#
#    Triceps skin fold thickness  2-Hour serum insulin   BMI  \
# 0                           35                     0  33.6
# 1                           29                     0  26.6
#
#    Diabetes pedigree function  Age  isdiabetic
# 0                       0.627   50           1
# 1                       0.351   31           0
#
#
# Check if there are any columns with empty/null dataset ?
# pregnantcount                   0
# Plasma glucose concentration    0
# Diastolic blood pressure        0
# Triceps skin fold thickness     0
# 2-Hour serum insulin            0
# BMI                             0
# Diabetes pedigree function      0
# Age                             0
# isdiabetic                      0
# dtype: int64
#
#
#
# ...

# %% [markdown]
# # 3. Data cleaning and pre-processing
# ---

# %%
# Calculate the median value for BMI and substitute it in the BMI column where its value is 0
# Reason: BMI of a human can't be 0
print(df.isin([0]).any())
print(end = '\n\n\n')

print('BMI', df['BMI'].median())
print(end = '\n\n\n')

df['BMI']=df['BMI'].replace(0,df['BMI'].median())


# Repeat the above step of data cleaning & transformation for all other relevant features
df['Plasma glucose concentration']=df['Plasma glucose concentration'].replace(0,df['Plasma glucose concentration'].median())
df['Diastolic blood pressure']=df['Diastolic blood pressure'].replace(0,df['Diastolic blood pressure'].median())
df['Triceps skin fold thickness']=df['Triceps skin fold thickness'].replace(0,df['Triceps skin fold thickness'].median())
df['2-Hour serum insulin']=df['2-Hour serum insulin'].replace(0,df['2-Hour serum insulin'].median())
df.isin([0]).any()
# Calculate the median value for each of them and substitute it in the respective column in place of 0
# Out:
# pregnantcount                    True
# Plasma glucose concentration     True
# Diastolic blood pressure         True
# Triceps skin fold thickness      True
# 2-Hour serum insulin             True
# BMI                              True
# Diabetes pedigree function      False
# Age                             False
# isdiabetic                       True
# dtype: bool
#
#
#
# BMI 32.0
# pregnantcount                    True
# Plasma glucose concentration    False
# Diastolic blood pressure        False
# Triceps skin fold thickness     False
# 2-Hour serum insulin            False
# BMI                             False
# Diabetes pedigree function      False
# Age                             False
# isdiabetic                       True
# dtype: bool

# %%
# to suppress any unwanted warnings
#--turn of warning messages
pd.options.mode.chained_assignment = None  # default='warn'
#----------------------------------------------------------------------
numeric_feature_names = ['pregnantcount','Plasma glucose concentration','Diastolic blood pressure','Triceps skin fold thickness','2-Hour serum insulin','BMI','Diabetes pedigree function','Age']
#--scale or normalize our two numeric score-based attributes
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()   # we are making the object of StandardScaler

# fit scaler on numeric features
ss.fit(df[numeric_feature_names])  # fit method learns the range of the data

# scale numeric features now
df[numeric_feature_names] = ss.transform(df[numeric_feature_names])
# transform method transforms the data. See the o/p. You would see a much reduced range.

# view updated feature-set
print(df)
# Out:
#      pregnantcount  Plasma glucose concentration  Diastolic blood pressure  \
# 0         0.639947                      0.866045                 -0.031990
# 1        -0.844885                     -1.205066                 -0.528319
# 2         1.233880                      2.016662                 -0.693761
# 3        -0.844885                     -1.073567                 -0.528319
# 4        -1.141852                      0.504422                 -2.679076
# ..             ...                           ...                       ...
# 763       1.827813                     -0.679069                  0.298896
# 764      -0.547919                      0.011301                 -0.197433
# 765       0.342981                     -0.021574                 -0.031990
# 766      -0.844885                      0.142800                 -1.024647
# 767      -0.844885                     -0.942068                 -0.197433
#
#      Triceps skin fold thickness  2-Hour serum insulin       BMI  \
# ...

# %% [markdown]
# # 4 Compare the accuracy

# %% [markdown]
# Note: Continue from the previous milestone on the same diabetes dataset
# Compare the accuracy for any 4 of the following Classifiers of your choice :
# LogisticRegression, KNeighborsClassifier, GaussianNB, SVC, LinearSVC,
# RandomForestClassifier, DecisionTreeClassifier by 24th Nov
# Hint: Compare all classifiers, using KFold CROSS VALIDATION strategy.

# %%
# Load libraries
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import cross_val_score

# %%
# Data Preprocessing
# Data preprocessing involves
# (1) Dividing the data into attributes and labels and
# (2) dividing the data into training and testing sets.
import warnings
warnings.filterwarnings("ignore")
# To divide the data into attributes and labels, do :
X = df.drop('isdiabetic', axis=1)
y = df['isdiabetic']

# the final preprocessing step is to divide data into training and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.10)


# Spot Check Algorithms
models = []
models.append(('LR', LogisticRegression(solver='liblinear', multi_class='ovr')))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC(gamma='auto')))
models.append(('RF',RandomForestClassifier(n_estimators=100)))
models.append(('ADA',AdaBoostClassifier(n_estimators=100)))
# evaluate each model in turn
validation_size = 0.2
seed = 0
scoring = 'accuracy'
results = []
names = []
for name, model in models:
    kfold = model_selection.KFold(n_splits=10)#, shuffle = True, random_state=seed
    cv_results = model_selection.cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.762733 (0.030544)
# LDA: 0.761263 (0.026411)
# KNN: 0.717826 (0.063451)
# CART: 0.674472 (0.055597)
# NB: 0.743892 (0.039653)
# SVM: 0.755466 (0.045790)
# RF: 0.753996 (0.044798)
# ADA: 0.743934 (0.044784)

# %%
# Compare Algorithms
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %%
//confusion_matrix
print('\n\n\n')
// Area Under the ROC Curve (AUC – ROC)
